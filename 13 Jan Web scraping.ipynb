# %% [markdown]
# # # Webscraping Project - Youtube

# %% [markdown]
# # Examining the hottest topics in "global breaking news" on 1st page of Youtube
#
# In this project I will be scraping the data obtained on the front page of Youtube after searching "global breaking news".
#
# I will parse the data and divide it into several categories and use this for my analysis.
#
# By analysing the data, we will examine what are the hottest headlines and topics in "global breaking news" according to Youtube.
#
# # Relevance to everyday life:
# - Code produces the results for "global breaking news" on the front page at any given time on Youtube.
# - Could help us answer : What do we find most important in our news source? What topics are we most interested in hearing about for global news? (eg. understanding our audience)

# %%
#Importing and installing libraries / packages 
import pandas as pd
import matplotlib.pyplot as plt

# %%
pip install python-dateutil #used to get accurate cleaning of time data
# Out:
# Requirement already satisfied: python-dateutil in /Users/joycechung/PycharmProjects/pythonProject/MyFirstProject/FirstVenv/lib/python3.10/site-packages (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/joycechung/PycharmProjects/pythonProject/MyFirstProject/FirstVenv/lib/python3.10/site-packages (from python-dateutil) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /Users/joycechung/SecondVenv/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: click in /Users/joycechung/SecondVenv/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /Users/joycechung/SecondVenv/lib/python3.10/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/joycechung/SecondVenv/lib/python3.10/site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /Users/joycechung/SecondVenv/lib/python3.10/site-packages (from nltk) (4.66.1)

# %%
from nltk.corpus import stopwords #used to clean the non-numerical data

# %%
pip install wordcloud #installing library to plot non-numerical data
# Out:
# Requirement already satisfied: wordcloud in /Users/joycechung/PycharmProjects/pythonProject/MyFirstProject/FirstVenv/lib/python3.10/site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /Users/joycechung/PycharmProjects/pythonProject/MyFirstProject/FirstVenv/lib/python3.10/site-packages (from wordcloud) (1.26.2)
# Requirement already satisfied: pillow in /Users/joycechung/PycharmProjects/pythonProject/MyFirstProject/FirstVenv/lib/python3.10/site-packages (from wordcloud) (10.1.0)
# Requirement already satisfied: matplotlib in /Users/joycechung/PycharmProjects/pythonProject/MyFirstProject/FirstVenv/lib/python3.10/site-packages (from wordcloud) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/joycechung/PycharmProjects/pythonProject/MyFirstProject/FirstVenv/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/joycechung/PycharmProjects/pythonProject/MyFirstProject/FirstVenv/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/joycechung/PycharmProjects/pythonProject/MyFirstProject/FirstVenv/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/joycechung/PycharmProjects/pythonProject/MyFirstProject/FirstVenv/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/joycechung/PycharmProjects/pythonProject/MyFirstProject/FirstVenv/lib/python3.10/site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/joycechung/PycharmProjects/pythonProject/MyFirstProject/FirstVenv/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/joycechung/PycharmProjects/pythonProject/MyFirstProject/FirstVenv/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/joycechung/PycharmProjects/pythonProject/MyFirstProject/FirstVenv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('/Users/joycechung/PycharmProjects/pythonProject/pythonProject/Unit 2 - Pandas, EDA.../Lessons & Exercises/Web Scraping Project/youtube_video_2024_01_18.csv', low_memory=False)
#how the scrape occured:
#The code used to webscrape and create the dataframe and load to csv is on Pycharm
#I used selenium to load the youtube webpage, and beautiful soup to parse the data 
#I used for loop to filter out the contents of the data eg. time-based content (time posted)
#Index-location is used to obtain the title and the caption, as well as the channel name.

#some elements such as "LIVE" which indicates any livestreaming videos, were filtered out. 
#Thus they are not posted in my dataset.

#the name of the project csv will change based on today's date
#the data in the csv will change based on the day

# %% [markdown]
# # Webscraping the search results page of Youtube using the phrase "global breaking news"
#
# I used the Selenium library on Pycharm to scrape the search engine results of this phrase from Youtube.
# On Pycharm, I parsed the data from a txt format into a dataframe that was loaded into a .csv file.
#
# The dataframe has several categories:
# title, views, time posted, channel name, and a preview of the caption (what is visible on the first page of Youtube immediately after the search phrase is entered.)
#
# Now, I am reading the .csv file. I will be cleaning this data with regular expressions and then using matplotlib to visualise the data to conduct analysis.

# %%
#The dataframe 
#original columns on the left, cleaned data is labelled on the right 

df
# Out:
#                                                 Title       Views  \
# 0   BC storm: Snowfall brings day of fun in Metro ...  4.3K views
# 1   How Hamas and Israel's information war is infl...  1.5K views
# 2       Pakistan accuses Iran of unprovoked airstrike  159K views
# 3   Global National: Jan. 17, 2024 | Heavy snowfal...   15K views
# 4   State Dept Asked Point Blank: 'Do You Think Ir...  126K views
# 5   Pentagon Spokesperson Answers Reporter Questio...  114K views
# 6   US Aid to Ukraine IS OVER: Zelensky Visits Dav...  103K views
# 7   Pakistan blames Iran for unprovoked airstrike ...  195K views
# 8   World Economic Forum for 2024 in Davos kicks o...   373 views
# 9   Leaked docs reveal world leaders are preparing...  282K views
# 10  Iran launches missile strikes in Pakistan, Ira...  184K views
# 11  Pakistan Attacks Iran: Operation Codename 'Mar...  3.6K views
# 12  CBC Vancouver News at 11, Jan 17 - Snow blanke...   558 views
# 13  Pakistan retaliation strikes hit targets in Ir...   19K views
# 14  CBC News: The National | B.C. snowstorm snarls...  4.2K views
# 15  Iran fires missiles at what it claims were Isr...  177K views
# 16  What conflict in the Red Sea could mean for gl...   20K views
# 17    U.S. continues strikes against Houthis in Yemen  457K views
# 18  BREAKING NEWS: Trump Claims That Biden Will Le...  206K views
# 19          Earth breaches critical warming threshold   21K views
#
#                 Time Posted            Channel Name  \
# 0               4 hours ago             Global News
# 1               4 hours ago             Global News
# 2              18 hours ago            CBS Mornings
# 3               5 hours ago             Global News
# 4              11 hours ago    Forbes Breaking News
# 5               7 hours ago    Forbes Breaking News
# 6                 1 day ago                The Hill
# 7              18 hours ago                CBS News
# 8                2 days ago            Arirang News
# 9                 1 day ago            Fox Business
# 10                1 day ago             Global News
# 11           24 minutes ago         Hindustan Times
# 12  Streamed 59 minutes ago           CBC Vancouver
# 13               1 hour ago                 DW News
# 14              2 hours ago  CBC News: The National
# 15                1 day ago       NEWS CENTER Maine
# 16                1 day ago       ABC News In-depth
# 17                1 day ago        CBS Evening News
# 18             5 months ago    Forbes Breaking News
# 19              1 month ago             Global News
#
#                                               Caption
# 0   The snowfall on B.C.'s South Coast Wednesday w...
# 1   While Hamas and Israel's violent conflict has ...
# 2   Tensions in the Middle East intensify as Pakis...
# 3   In tonight's top story: While the rest of Cana...
# 4   State Department spokesperson Matthew Miller w...
# 5   On Wednesday, Pentagon Spokesperson Major Gene...
# 6   Briahna Joy Gray and Robby Soave discuss updat...
# 7   Tensions in the Middle East intensify as Pakis...
# 8   다보스포럼 개막 안보 위기 고조 속 해법 모색 The annual World Eco...
# 9   Rep. Pat Fallon, R-Texas, discusses the ongoin...
# 10  Iran has launched a series of deadly attacks i...
# 11  Pakistan government on January 18 confirmed th...
# 12  Watch CBC Vancouver News with host Dan Burritt...
# 13  Pakistan said Thursday it had conducted overni...
# 14  Jan. 17, 2024 | As much as 30 centimetres of s...
# 15  The missile strikes were near the U.S. Consula...
# 16  Attacks on shipping in the Red Sea, including ...
# 17  "CBS Evening News with Norah O'Donnell" delive...
# 18  In a video released to social media, former Pr...
# 19                                                NaN

# %% [markdown]
# # Data Cleaning

# %%
#Cleaning the Views data into numerical format with regular expression
import re

# Define a function to clean the views data
def clean_views(views):
    if views:
        value = re.findall(r'(\d+(\.\d+)?)([KM])', views)
        if value:
            value, decimal, multiplier = value[0]
            value = float(value)
            
            if multiplier == 'K':
                value *= 1000
            elif multiplier == 'M':
                value *= 1000000

            return int(value)
    
    return None

# Apply the clean_views function to create a new column 'Views_Cleaned'
df['Views Cleaned'] = df['Views'].apply(clean_views)

# %%
import re
from datetime import datetime
from dateutil.relativedelta import relativedelta # represents an interval of time.

# Define a function to clean the time values
#regular expression
def clean_time(time):
    value = re.findall(r'(\d+)', time)
    unit = re.findall(r'(hour|day|month|minute)', time)
    
    if value and unit:
        value = int(value[0])
        unit = unit[0]
        
        if unit == 'hour':
            return value
        elif unit == 'day':
            return value * 24
        elif unit == 'month':
            current_date = datetime.now().replace(hour=0, minute=0, second=0, microsecond=0)
            target_date = current_date - relativedelta(months=value)  #because different months have different lengths
            hours_diff = (current_date - target_date).days * 24
            return hours_diff
        elif unit == 'minute': #so that videos posted under 1 hour ago are not NaN values, however they still show up as value '0'
            return value // 60
    
    return None

# Apply the clean_time function to create a new column 'Time Posted Cleaned'
df['Time Posted Cleaned'] = df['Time Posted'].apply(clean_time)

# %%
#Splitting up the non-numerical data (video title, channel name, caption) into words by using white-space separator

# Define functions to split the non-numerical data into words
def split_title(title):
    if isinstance(title, str):
        return title.split()
    else:
        return []

def split_channel_name(channel_name):
    if isinstance(channel_name, str):
        return channel_name.split()
    else:
        return []

def split_caption(caption):
    if isinstance(caption, str):
        return caption.split()
    else:
        return []

# Apply the split functions to create new columns with the split words
df['Title_Split'] = df['Title'].apply(split_title)
df['Channel_Name_Split'] = df['Channel Name'].apply(split_channel_name)
df['Caption_Split'] = df['Caption'].apply(split_caption)

# %% [markdown]
# # Data Summarisation
# Reducing video title, channel name and caption into the key points. (removing stop words)

# %%
#Removing stopwords from the non-numerical data
import nltk
from nltk.corpus import stopwords

# Create a function to clean the data and remove stop words
def clean_data(column):
    # Concatenate all the lists of words in the column
    all_words = [word for sublist in column for word in sublist]
    
    # Remove stop words
    sr = stopwords.words('english')
    clean_words = [word for word in all_words if word not in sr]
    
    return clean_words

# Clean the data for 'Title_Split'
cleaned_title = clean_data(df['Title_Split'])

# Clean the data for 'Channel_Name_Split'
cleaned_channel_name = clean_data(df['Channel_Name_Split'])

# Clean the data for 'Caption_Split'
cleaned_caption = clean_data(df['Caption_Split'])

# %%
#Looking at the type of data collected (old and cleaned)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                20 non-null     object
#  1   Views                20 non-null     object
#  2   Time Posted          20 non-null     object
#  3   Channel Name         20 non-null     object
#  4   Caption              19 non-null     object
#  5   Views Cleaned        18 non-null     float64
#  6   Time Posted Cleaned  20 non-null     int64
#  7   Title_Split          20 non-null     object
#  8   Channel_Name_Split   20 non-null     object
#  9   Caption_Split        20 non-null     object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.7+ KB

# %% [markdown]
# # Non-Numerical Data Visualisation
# - What are the most popular key-words in the title of these Youtube videos?
# - Which channels are most of these videos being posted by?
# - What are the most popular key-words in the caption?

# %%
# Creating a frequency plot for title, channel name and caption 
# outputs the 20 most frequently used words for each column

# %%
import nltk
import matplotlib.pyplot as plt

# Create a function to compute the frequency distribution and plot the frequency plot
def compute_frequency_plot(data, plot_title):
    # Compute the frequency distribution
    freq = nltk.FreqDist(data)
    
    # Plot the frequency distribution
    freq.plot(20, cumulative=False, title=plot_title)
    plt.show()

# %%
# Compute and plot the frequency distribution for 'Title_Split'
compute_frequency_plot(cleaned_title, "Title_Split Frequency Plot")

# %%
# Compute and plot the frequency distribution for 'Channel_Name_Split'
compute_frequency_plot(cleaned_channel_name, "Channel_Name_Split Frequency Plot")

# %%
# Compute and plot the frequency distribution for 'Caption_Split'
compute_frequency_plot(cleaned_caption, "Caption_Split Frequency Plot")

# %%
#Using wordcloud to visualise the frequency of words used for channel name, caption and video title.

# %%
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Create a function to generate a word cloud
def generate_wordcloud(data, plot_title):
    # Concatenate all the cleaned words in the data
    text = ' '.join(data)
    
    # Create a WordCloud object
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    
    # Plot the word cloud
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(plot_title)
    plt.show()

# %%
# Generate word cloud for 'Title_Split'
generate_wordcloud(cleaned_title, "Word Cloud for Title_Split")

# %%
# Generate word cloud for 'Channel_Name_Split'
generate_wordcloud(cleaned_channel_name, "Word Cloud for Channel_Name_Split")

# %%
# Generate word cloud for 'Caption_Split'
generate_wordcloud(cleaned_caption, "Word Cloud for Caption_Split")

# %% [markdown]
# # Numerical Data Visualisation
# - Which videos have the most views?
# - Which videos were posted the most recently on the Youtube page?

# %%
#Videos with the most views 

# Sort the dataframe by 'Views Cleaned' column in descending order to get the videos with the most views
most_viewed_videos = df.sort_values('Views Cleaned', ascending=False).head(10)

# Plot the videos with the most views using a horizontal bar chart
plt.figure(figsize=(10, 5))
plt.barh(most_viewed_videos['Title'], most_viewed_videos['Views Cleaned'])
plt.xlabel('Views')
plt.ylabel('Video Title')
plt.title('Videos with the Most Views')
plt.show()

# %%
#Table of most recent videos 
# Sort the dataframe by 'Time Posted Cleaned' column in ascending order
sorted_df = df.sort_values('Time Posted Cleaned', ascending=True)

# Print the sorted data with corresponding titles
for index, row in sorted_df.iterrows():
    title = row['Title']
    time_posted_cleaned = row['Time Posted Cleaned']
    print(f"Title: {title}")
    print(f"Time Posted: {time_posted_cleaned}")
    print()
# Out:
# Title: Pakistan Attacks Iran: Operation Codename 'Marg Bar Sarmachar'; Army Says Intel Of Terror Plot To...
# Time Posted: 0
#
# Title: CBC Vancouver News at 11, Jan 17 - Snow blankets southwest B.C., slowing travel and closing schools
# Time Posted: 0
#
# Title: Pakistan retaliation strikes hit targets in Iran | DW News
# Time Posted: 1
#
# Title: CBC News: The National | B.C. snowstorm snarls roads, knocks out power
# Time Posted: 2
#
# Title: BC storm: Snowfall brings day of fun in Metro Vancouver
# Time Posted: 4
#
# Title: How Hamas and Israel's information war is influencing public opinion of conflict
# Time Posted: 4
#
# Title: Global National: Jan. 17, 2024 | Heavy snowfall brings southwestern BC to a standstill
# Time Posted: 5
#
# Title: Pentagon Spokesperson Answers Reporter Questions On Recent US Strike Against Houthi Troops
# Time Posted: 7
#
# Title: State Dept Asked Point Blank: 'Do You Think Iran Has The Right To Defend Itself As The US Would?'
# Time Posted: 11
#
# Title: Pakistan accuses Iran of unprovoked airstrike
# Time Posted: 18
#
# Title: Pakistan blames Iran for unprovoked airstrike as Middle East tensions escalate
# Time Posted: 18
#
# Title: U.S. continues strikes against Houthis in Yemen
# Time Posted: 24
#
# Title: What conflict in the Red Sea could mean for global supply chains | 7.30
# Time Posted: 24
#
# Title: Iran fires missiles at what it claims were Israeli spy headquarters in northern Iraq
# Time Posted: 24
#
# Title: Leaked docs reveal world leaders are preparing for Russia to launch World War 3: report
# Time Posted: 24
#
# Title: US Aid to Ukraine IS OVER: Zelensky Visits Davos World Economic Forum to BEG for More Money: Rising
# Time Posted: 24
#
# Title: Iran launches missile strikes in Pakistan, Iraq, Syria
# Time Posted: 24
#
# Title: World Economic Forum for 2024 in Davos kicks off amid global security turmoil
# Time Posted: 48
#
# Title: Earth breaches critical warming threshold
# Time Posted: 744
#
# Title: BREAKING NEWS: Trump Claims That Biden Will Lead U.S. Into World War III, Is 'Mental Catastrophe'
# Time Posted: 3672

# %%
sorted_df
# Out:
#                                                 Title       Views  \
# 11  Pakistan Attacks Iran: Operation Codename 'Mar...  3.6K views
# 12  CBC Vancouver News at 11, Jan 17 - Snow blanke...   558 views
# 13  Pakistan retaliation strikes hit targets in Ir...   19K views
# 14  CBC News: The National | B.C. snowstorm snarls...  4.2K views
# 0   BC storm: Snowfall brings day of fun in Metro ...  4.3K views
# 1   How Hamas and Israel's information war is infl...  1.5K views
# 3   Global National: Jan. 17, 2024 | Heavy snowfal...   15K views
# 5   Pentagon Spokesperson Answers Reporter Questio...  114K views
# 4   State Dept Asked Point Blank: 'Do You Think Ir...  126K views
# 2       Pakistan accuses Iran of unprovoked airstrike  159K views
# 7   Pakistan blames Iran for unprovoked airstrike ...  195K views
# 17    U.S. continues strikes against Houthis in Yemen  457K views
# 16  What conflict in the Red Sea could mean for gl...   20K views
# 15  Iran fires missiles at what it claims were Isr...  177K views
# 9   Leaked docs reveal world leaders are preparing...  282K views
# 6   US Aid to Ukraine IS OVER: Zelensky Visits Dav...  103K views
# 10  Iran launches missile strikes in Pakistan, Ira...  184K views
# 8   World Economic Forum for 2024 in Davos kicks o...   373 views
# 19          Earth breaches critical warming threshold   21K views
# 18  BREAKING NEWS: Trump Claims That Biden Will Le...  206K views
#
#                 Time Posted            Channel Name  \
# 11           24 minutes ago         Hindustan Times
# 12  Streamed 59 minutes ago           CBC Vancouver
# 13               1 hour ago                 DW News
# 14              2 hours ago  CBC News: The National
# 0               4 hours ago             Global News
# 1               4 hours ago             Global News
# 3               5 hours ago             Global News
# 5               7 hours ago    Forbes Breaking News
# 4              11 hours ago    Forbes Breaking News
# 2              18 hours ago            CBS Mornings
# 7              18 hours ago                CBS News
# 17                1 day ago        CBS Evening News
# 16                1 day ago       ABC News In-depth
# 15                1 day ago       NEWS CENTER Maine
# 9                 1 day ago            Fox Business
# 6                 1 day ago                The Hill
# 10                1 day ago             Global News
# 8                2 days ago            Arirang News
# 19              1 month ago             Global News
# 18             5 months ago    Forbes Breaking News
#
#                                               Caption  Views Cleaned  \
# 11  Pakistan government on January 18 confirmed th...         3600.0
# 12  Watch CBC Vancouver News with host Dan Burritt...            NaN
# 13  Pakistan said Thursday it had conducted overni...        19000.0
# 14  Jan. 17, 2024 | As much as 30 centimetres of s...         4200.0
# 0   The snowfall on B.C.'s South Coast Wednesday w...         4300.0
# 1   While Hamas and Israel's violent conflict has ...         1500.0
# 3   In tonight's top story: While the rest of Cana...        15000.0
# 5   On Wednesday, Pentagon Spokesperson Major Gene...       114000.0
# 4   State Department spokesperson Matthew Miller w...       126000.0
# 2   Tensions in the Middle East intensify as Pakis...       159000.0
# 7   Tensions in the Middle East intensify as Pakis...       195000.0
# 17  "CBS Evening News with Norah O'Donnell" delive...       457000.0
# 16  Attacks on shipping in the Red Sea, including ...        20000.0
# 15  The missile strikes were near the U.S. Consula...       177000.0
# 9   Rep. Pat Fallon, R-Texas, discusses the ongoin...       282000.0
# 6   Briahna Joy Gray and Robby Soave discuss updat...       103000.0
# 10  Iran has launched a series of deadly attacks i...       184000.0
# 8   다보스포럼 개막 안보 위기 고조 속 해법 모색 The annual World Eco...            NaN
# 19                                                NaN        21000.0
# 18  In a video released to social media, former Pr...       206000.0
#
#     Time Posted Cleaned                                        Title_Split  \
# 11                    0  [Pakistan, Attacks, Iran:, Operation, Codename...
# 12                    0  [CBC, Vancouver, News, at, 11,, Jan, 17, -, Sn...
# 13                    1  [Pakistan, retaliation, strikes, hit, targets,...
# 14                    2  [CBC, News:, The, National, |, B.C., snowstorm...
# 0                     4  [BC, storm:, Snowfall, brings, day, of, fun, i...
# 1                     4  [How, Hamas, and, Israel's, information, war, ...
# 3                     5  [Global, National:, Jan., 17,, 2024, |, Heavy,...
# 5                     7  [Pentagon, Spokesperson, Answers, Reporter, Qu...
# 4                    11  [State, Dept, Asked, Point, Blank:, 'Do, You, ...
# 2                    18  [Pakistan, accuses, Iran, of, unprovoked, airs...
# 7                    18  [Pakistan, blames, Iran, for, unprovoked, airs...
# 17                   24  [U.S., continues, strikes, against, Houthis, i...
# 16                   24  [What, conflict, in, the, Red, Sea, could, mea...
# 15                   24  [Iran, fires, missiles, at, what, it, claims, ...
# 9                    24  [Leaked, docs, reveal, world, leaders, are, pr...
# 6                    24  [US, Aid, to, Ukraine, IS, OVER:, Zelensky, Vi...
# 10                   24  [Iran, launches, missile, strikes, in, Pakista...
# 8                    48  [World, Economic, Forum, for, 2024, in, Davos,...
# 19                  744    [Earth, breaches, critical, warming, threshold]
# 18                 3672  [BREAKING, NEWS:, Trump, Claims, That, Biden, ...
#
#              Channel_Name_Split  \
# 11           [Hindustan, Times]
# 12             [CBC, Vancouver]
# 13                   [DW, News]
# 14  [CBC, News:, The, National]
# 0                [Global, News]
# 1                [Global, News]
# 3                [Global, News]
# 5      [Forbes, Breaking, News]
# 4      [Forbes, Breaking, News]
# 2               [CBS, Mornings]
# 7                   [CBS, News]
# 17         [CBS, Evening, News]
# 16        [ABC, News, In-depth]
# 15        [NEWS, CENTER, Maine]
# 9               [Fox, Business]
# 6                   [The, Hill]
# 10               [Global, News]
# 8               [Arirang, News]
# 19               [Global, News]
# 18     [Forbes, Breaking, News]
#
#                                         Caption_Split
# 11  [Pakistan, government, on, January, 18, confir...
# 12  [Watch, CBC, Vancouver, News, with, host, Dan,...
# 13  [Pakistan, said, Thursday, it, had, conducted,...
# 14  [Jan., 17,, 2024, |, As, much, as, 30, centime...
# 0   [The, snowfall, on, B.C.'s, South, Coast, Wedn...
# 1   [While, Hamas, and, Israel's, violent, conflic...
# 3   [In, tonight's, top, story:, While, the, rest,...
# 5   [On, Wednesday,, Pentagon, Spokesperson, Major...
# 4   [State, Department, spokesperson, Matthew, Mil...
# 2   [Tensions, in, the, Middle, East, intensify, a...
# 7   [Tensions, in, the, Middle, East, intensify, a...
# 17  ["CBS, Evening, News, with, Norah, O'Donnell",...
# 16  [Attacks, on, shipping, in, the, Red, Sea,, in...
# 15  [The, missile, strikes, were, near, the, U.S.,...
# 9   [Rep., Pat, Fallon,, R-Texas,, discusses, the,...
# 6   [Briahna, Joy, Gray, and, Robby, Soave, discus...
# 10  [Iran, has, launched, a, series, of, deadly, a...
# 8   [다보스포럼, 개막, 안보, 위기, 고조, 속, 해법, 모색, The, annual...
# 19                                                 []
# 18  [In, a, video, released, to, social, media,, f...

# %% [markdown]
# # Further analysis:
#
# From the video that attracted the most views, what are the most frequent keywords from its title and caption?

# %%
from collections import Counter
from nltk.corpus import stopwords

# Get the top most viewed video
top_most_viewed_video = df.sort_values('Views Cleaned', ascending=False).iloc[0]

# Clean the title
title = top_most_viewed_video['Title_Split']
cleaned_title = [word for word in title if word not in stopwords.words('english')]

# Clean the caption
caption = top_most_viewed_video['Caption_Split']
cleaned_caption = [word for word in caption if word not in stopwords.words('english')]

# Extract keywords from the title and caption
title_keywords = set(cleaned_title)
caption_keywords = set(cleaned_caption)

# Combine the keywords from title and caption
keywords = title_keywords.union(caption_keywords)

# Calculate the frequency of each keyword
keyword_frequencies = Counter(keywords)

# Get the most common keywords and their frequencies
top_keywords = keyword_frequencies.most_common(10)
top_keywords, frequencies = zip(*top_keywords)

# Print the most common keywords and their frequencies
for keyword, frequency in zip(top_keywords, frequencies):
    print(f"Keyword: {keyword.strip()}")
    print(f"Frequency: {frequency}")
    print()
# Out:
# Keyword: beyond
# Frequency: 1
#
# Keyword: Houthis
# Frequency: 1
#
# Keyword: goes
# Frequency: 1
#
# Keyword: delivers
# Frequency: 1
#
# Keyword: ...
# Frequency: 1
#
# Keyword: News
# Frequency: 1
#
# Keyword: original
# Frequency: 1
#
# Keyword: headlines
# Frequency: 1
#
# Keyword: news
# Frequency: 1
#
# Keyword: "CBS
# Frequency: 1

# %% [markdown]
# Conclusion:
#
# Q: From the deeper analysis, can we deduce the hottest topics re: global breaking news these days?
#
#
# A:
# If we're basing the "hotness" of a topic on total number of views and frequency of keywords, then we identified some of the hottest topics for this search term on Youtube
#
# We can also see when the video containing the hottest topic was published and the channel name.

# %% [markdown]
# Evaluation:
#
# This code only extracts what is seen on the front page of Youtube.
# It doesn't look at the next couple of pages which may skew our results as it reduces the total sample size of the data.
#
# I didn't program Selenium to click into the videos to get the full caption and more details on the video.
#
# If I had done that, my analysis might be even more comprehensive.
